# %%
import json, random, time, datetime
import redis

server = redis.Redis(host='localhost', port=6379, db=0)

SENSOR_ID = "wtf-pipe-1"

def generate_reading():
    return {
        "timestamp": datetime.datetime.now().isoformat() + 'Z',
        "sensor_id": SENSOR_ID,
        "temperature": round(random.uniform(10, 35), 1),
        "pressure": round(random.uniform(1.0, 3.0), 2),
        "flow": round(random.uniform(20, 100), 1)
    }
count = 0
while count < 20:
    reading = generate_reading()
    print(f"Publishing reading: {reading}")
    server.publish('sensor_data', str(reading)) #json.dumps(reading))
    count += 1
    time.sleep(2)
# Out:
# Publishing reading: {'timestamp': '2025-05-27T12:54:43.207045Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 13.6, 'pressure': 1.52, 'flow': 40.5}
# Publishing reading: {'timestamp': '2025-05-27T12:54:45.212780Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 22.5, 'pressure': 2.2, 'flow': 43.9}
# Publishing reading: {'timestamp': '2025-05-27T12:54:47.214884Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 26.4, 'pressure': 1.81, 'flow': 30.7}
# Publishing reading: {'timestamp': '2025-05-27T12:54:49.216363Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 31.4, 'pressure': 2.97, 'flow': 86.8}
# Publishing reading: {'timestamp': '2025-05-27T12:54:51.218125Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 21.7, 'pressure': 1.89, 'flow': 93.9}
# Publishing reading: {'timestamp': '2025-05-27T12:54:53.219451Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 29.6, 'pressure': 2.5, 'flow': 53.8}
# Publishing reading: {'timestamp': '2025-05-27T12:54:55.221136Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 28.9, 'pressure': 1.45, 'flow': 88.2}
# Publishing reading: {'timestamp': '2025-05-27T12:54:57.223155Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 23.7, 'pressure': 2.55, 'flow': 58.0}
# Publishing reading: {'timestamp': '2025-05-27T12:54:59.224931Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 19.5, 'pressure': 1.32, 'flow': 70.3}
# Publishing reading: {'timestamp': '2025-05-27T12:55:01.226463Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 22.3, 'pressure': 1.7, 'flow': 53.1}
# Publishing reading: {'timestamp': '2025-05-27T12:55:03.227996Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 26.0, 'pressure': 1.23, 'flow': 30.9}
# Publishing reading: {'timestamp': '2025-05-27T12:55:05.229380Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 22.4, 'pressure': 1.54, 'flow': 77.1}
# Publishing reading: {'timestamp': '2025-05-27T12:55:07.230997Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 11.9, 'pressure': 1.39, 'flow': 51.5}
# Publishing reading: {'timestamp': '2025-05-27T12:55:09.233102Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 27.2, 'pressure': 1.57, 'flow': 75.3}
# Publishing reading: {'timestamp': '2025-05-27T12:55:11.235042Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 33.4, 'pressure': 1.31, 'flow': 95.9}
# Publishing reading: {'timestamp': '2025-05-27T12:55:13.236571Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 18.5, 'pressure': 1.94, 'flow': 22.2}
# Publishing reading: {'timestamp': '2025-05-27T12:55:15.238311Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 22.8, 'pressure': 2.5, 'flow': 29.2}
# Publishing reading: {'timestamp': '2025-05-27T12:55:17.239893Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 35.0, 'pressure': 1.56, 'flow': 38.5}
# Publishing reading: {'timestamp': '2025-05-27T12:55:19.241561Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 28.1, 'pressure': 1.67, 'flow': 77.5}
# Publishing reading: {'timestamp': '2025-05-27T12:55:21.243819Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 23.1, 'pressure': 1.7, 'flow': 85.6}

# %%
import json, time, datetime
import redis
from collections import deque

r = redis.Redis(host='localhost', port=6379, db=0)

sub = r.pubsub()
sub.subscribe('sensor_data')

WINDOW = deque(maxlen=10)  # for drift
DRIFT_THRESHOLD = 38.0
SPIKE_THRESHOLDS = {'pressure': 4.0, 'flow': 120.0}
DROPOUT_SECONDS = 10

last_timestamp = time.time()

def detect_anomalies(data):
    global last_timestamp
    now = time.time()
    last_timestamp = now
    anomalies = []

    # Spike detection
    for param, threshold in SPIKE_THRESHOLDS.items():
        if data[param] > threshold:
            anomalies.append({
                "type": "spike",
                "timestamp": data["timestamp"],
                "sensor_id": data["sensor_id"],
                "parameter": param,
                "value": data[param],
                "message": f"{param.title()} spike detected: {data[param]}"
            })

    # Drift detection
    WINDOW.append(data)
    temps = [x['temperature'] for x in WINDOW]
    if all(t > DRIFT_THRESHOLD for t in temps) and len(WINDOW) == WINDOW.maxlen:
        anomalies.append({
            "type": "drift",
            "timestamp": data["timestamp"],
            "sensor_id": data["sensor_id"],
            "parameter": "temperature",
            "value": temps[-1],
            "duration_seconds": 20,
            "message": f"Temperature drift detected over 20 seconds."
        })
        WINDOW.clear()

    if anomalies:
        with open("./storage/anomaly_log.json", "a") as f:
            for a in anomalies:
                f.write(json.dumps(a) + "\n")

for msg in sub.listen():
    print(msg, msg['data'])
    if msg['type'] == 'message':
        print(f"Received message: {msg['data'].decode('utf-8')}")
    continue
        # detect_anomalies(json.loads(msg['data']))
# Out:
# {'type': 'subscribe', 'pattern': None, 'channel': b'sensor_data', 'data': 1} 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 55
#      52             for a in anomalies:
#      53                 f.write(json.dumps(a) + "\n")
# ---> 55 for msg in sub.listen():
#      56     print(msg, msg['data'])
#      57     if msg['type'] == 'message':
#
# File ~/Documents/Savannah/svt/lib/python3.13/site-packages/redis/client.py:1099, in PubSub.listen(self)
#    1097 "Listen for messages on channels this client has been subscribed to"
#    1098 while self.subscribed:
# -> 1099     response = self.handle_message(self.parse_response(block=True))
#    1100     if response is not None:
#    1101         yield response
#
# File ~/Documents/Savannah/svt/lib/python3.13/site-packages/redis/client.py:938, in PubSub.parse_response(self, block, timeout)
#     935         conn.connect()
#     936     return conn.read_response(disconnect_on_error=False, push_request=True)
# --> 938 response = self._execute(conn, try_read)
#     940 if self.is_health_check_response(response):
#     941     # ignore the health check message as user might not expect it
#     942     self.health_check_response_counter -= 1
#
# File ~/Documents/Savannah/svt/lib/python3.13/site-packages/redis/client.py:914, in PubSub._execute(self, conn, command, *args, **kwargs)
#     906 def _execute(self, conn, command, *args, **kwargs):
#     907     """
#     908     Connect manually upon disconnection. If the Redis server is down,
#     909     this will fail and raise a ConnectionError as desired.
#    (...)    912     patterns we were previously listening to
#     913     """
# --> 914     return conn.retry.call_with_retry(
#     915         lambda: command(*args, **kwargs),
#     916         lambda _: self._reconnect(conn),
#     917     )
#
# File ~/Documents/Savannah/svt/lib/python3.13/site-packages/redis/retry.py:87, in Retry.call_with_retry(self, do, fail)
#      85 while True:
#      86     try:
# ---> 87         return do()
#      88     except self._supported_errors as error:
#      89         failures += 1
#
# File ~/Documents/Savannah/svt/lib/python3.13/site-packages/redis/client.py:915, in PubSub._execute.<locals>.<lambda>()
#     906 def _execute(self, conn, command, *args, **kwargs):
#     907     """
#     908     Connect manually upon disconnection. If the Redis server is down,
#     909     this will fail and raise a ConnectionError as desired.
#    (...)    912     patterns we were previously listening to
#     913     """
#     914     return conn.retry.call_with_retry(
# --> 915         lambda: command(*args, **kwargs),
#     916         lambda _: self._reconnect(conn),
#     917     )
#
# File ~/Documents/Savannah/svt/lib/python3.13/site-packages/redis/client.py:936, in PubSub.parse_response.<locals>.try_read()
#     934 else:
#     935     conn.connect()
# --> 936 return conn.read_response(disconnect_on_error=False, push_request=True)
#
# File ~/Documents/Savannah/svt/lib/python3.13/site-packages/redis/connection.py:644, in AbstractConnection.read_response(self, disable_decoding, disconnect_on_error, push_request)
#     640         response = self._parser.read_response(
#     641             disable_decoding=disable_decoding, push_request=push_request
#     642         )
#     643     else:
# --> 644         response = self._parser.read_response(disable_decoding=disable_decoding)
#     645 except socket.timeout:
#     646     if disconnect_on_error:
#
# File ~/Documents/Savannah/svt/lib/python3.13/site-packages/redis/_parsers/resp2.py:15, in _RESP2Parser.read_response(self, disable_decoding)
#      13 pos = self._buffer.get_pos() if self._buffer else None
#      14 try:
# ---> 15     result = self._read_response(disable_decoding=disable_decoding)
#      16 except BaseException:
#      17     if self._buffer:
#
# File ~/Documents/Savannah/svt/lib/python3.13/site-packages/redis/_parsers/resp2.py:25, in _RESP2Parser._read_response(self, disable_decoding)
#      24 def _read_response(self, disable_decoding=False):
# ---> 25     raw = self._buffer.readline()
#      26     if not raw:
#      27         raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
#
# File ~/Documents/Savannah/svt/lib/python3.13/site-packages/redis/_parsers/socket.py:115, in SocketBuffer.readline(self)
#     112 data = buf.readline()
#     113 while not data.endswith(SYM_CRLF):
#     114     # there's more data in the socket that we need
# --> 115     self._read_from_socket()
#     116     data += buf.readline()
#     118 return data[:-2]
#
# File ~/Documents/Savannah/svt/lib/python3.13/site-packages/redis/_parsers/socket.py:65, in SocketBuffer._read_from_socket(self, length, timeout, raise_on_timeout)
#      63 try:
#      64     while True:
# ---> 65         data = self._sock.recv(socket_read_size)
#      66         # an empty string indicates the server shutdown the socket
#      67         if isinstance(data, bytes) and len(data) == 0:
#
# KeyboardInterrupt:

# %%
import json, time, datetime
import redis
from collections import deque
import random
import os

SENSOR_ID = "wtf-pipe-1"

def generate_reading():
    return {
        "timestamp": datetime.datetime.now().isoformat() + 'Z',
        "sensor_id": SENSOR_ID,
        "temperature": round(random.uniform(10, 50), 1),
        "pressure": round(random.uniform(1.0, 5.0), 2),
        "flow": round(random.uniform(20, 130), 1)
    }


WINDOW = deque(maxlen=10)  # for drift
DRIFT_THRESHOLD = 38.0
SPIKE_THRESHOLDS = {'pressure': 4.0, 'flow': 120.0}
DROPOUT_SECONDS = 10

def detect_anomalies(data:dict):
    global last_timestamp
    now = time.time()
    last_timestamp = now
    anomalies = []

    # Spike detection
    for param, threshold in SPIKE_THRESHOLDS.items():
        if data[param] > threshold:
            print(f"Spike detected: {param} = {data[param]}")
            anomalies.append({
                "type": "spike",
                "timestamp": data["timestamp"],
                "sensor_id": data["sensor_id"],
                "parameter": param,
                "value": data[param],
                "message": f"{param.title()} spike detected: {data[param]}"
            })

    # Drift detection
    WINDOW.append(data)
    temps = [x['temperature'] for x in WINDOW]
    if all(t > DRIFT_THRESHOLD for t in temps) and len(WINDOW) == WINDOW.maxlen:
        print(f"Drift detected: temperature = {temps[-1]}")
        anomalies.append({
            "type": "drift",
            "timestamp": data["timestamp"],
            "sensor_id": data["sensor_id"],
            "parameter": "temperature",
            "value": temps[-1],
            "duration_seconds": 20,
            "message": f"Temperature drift detected over 20 seconds."
        })
        WINDOW.clear()

    if now - last_timestamp > DROPOUT_SECONDS:
        anomalies.append({
            "type": "dropout",
            "timestamp": datetime.datetime.now().isoformat(),
            "sensor_id": SENSOR_ID,
            "parameter": "all",
            "message": f"No data received in {int(now - last_timestamp)} seconds."
        })


    if anomalies:
        log_path = os.path.join("storage", "anomaly_log.json")
        os.makedirs(os.path.dirname(log_path), exist_ok=True)
        with open(log_path, "a") as f:
            for a in anomalies:
                f.write(json.dumps(a) + "\n")


count = 0
while count < 100:
    reading = generate_reading()
    print(f"Publishing reading: {reading}")

    detect_anomalies(reading)
    count += 1
    time.sleep(2) # Sleep to avoid busy waiting
# Out:
# Publishing reading: {'timestamp': '2025-06-02T15:43:05.983693Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 35.3, 'pressure': 3.64, 'flow': 116.9}
# Publishing reading: {'timestamp': '2025-06-02T15:43:07.983930Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 33.4, 'pressure': 3.74, 'flow': 95.5}
# Publishing reading: {'timestamp': '2025-06-02T15:43:09.984295Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 37.8, 'pressure': 2.49, 'flow': 114.8}
# Publishing reading: {'timestamp': '2025-06-02T15:43:11.984574Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 25.1, 'pressure': 1.71, 'flow': 117.9}
# Publishing reading: {'timestamp': '2025-06-02T15:43:13.984792Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 18.7, 'pressure': 2.46, 'flow': 85.9}
# Publishing reading: {'timestamp': '2025-06-02T15:43:15.985007Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 17.6, 'pressure': 1.2, 'flow': 98.4}
# Publishing reading: {'timestamp': '2025-06-02T15:43:17.985244Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 36.6, 'pressure': 1.08, 'flow': 55.5}
# Publishing reading: {'timestamp': '2025-06-02T15:43:19.985469Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 10.1, 'pressure': 2.73, 'flow': 87.8}
# Publishing reading: {'timestamp': '2025-06-02T15:43:21.985681Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 21.8, 'pressure': 2.75, 'flow': 106.3}
# Publishing reading: {'timestamp': '2025-06-02T15:43:23.985955Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 35.3, 'pressure': 3.23, 'flow': 91.9}
# Publishing reading: {'timestamp': '2025-06-02T15:43:25.986447Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 12.8, 'pressure': 2.5, 'flow': 89.8}
# Publishing reading: {'timestamp': '2025-06-02T15:43:27.986852Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 18.1, 'pressure': 3.66, 'flow': 101.6}
# Publishing reading: {'timestamp': '2025-06-02T15:43:29.987112Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 28.5, 'pressure': 1.3, 'flow': 97.1}
# Publishing reading: {'timestamp': '2025-06-02T15:43:31.987318Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 16.5, 'pressure': 3.98, 'flow': 124.9}
# Spike detected: flow = 124.9
# Publishing reading: {'timestamp': '2025-06-02T15:43:33.996892Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 20.0, 'pressure': 3.12, 'flow': 95.5}
# Publishing reading: {'timestamp': '2025-06-02T15:43:35.997223Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 18.2, 'pressure': 2.32, 'flow': 55.7}
# Publishing reading: {'timestamp': '2025-06-02T15:43:37.997510Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 23.8, 'pressure': 3.65, 'flow': 22.3}
# Publishing reading: {'timestamp': '2025-06-02T15:43:39.997781Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 20.7, 'pressure': 2.13, 'flow': 42.8}
# Publishing reading: {'timestamp': '2025-06-02T15:43:41.998080Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 27.9, 'pressure': 2.48, 'flow': 32.7}
# Publishing reading: {'timestamp': '2025-06-02T15:43:43.998857Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 13.6, 'pressure': 1.11, 'flow': 67.9}
# Publishing reading: {'timestamp': '2025-06-02T15:43:45.999406Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 38.6, 'pressure': 3.5, 'flow': 70.6}
# Publishing reading: {'timestamp': '2025-06-02T15:43:47.999779Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 20.8, 'pressure': 3.62, 'flow': 87.1}
# Publishing reading: {'timestamp': '2025-06-02T15:43:50.000006Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 36.3, 'pressure': 1.2, 'flow': 110.1}
# Publishing reading: {'timestamp': '2025-06-02T15:43:52.000217Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 16.0, 'pressure': 2.15, 'flow': 50.6}
# Publishing reading: {'timestamp': '2025-06-02T15:43:54.000468Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 21.5, 'pressure': 1.71, 'flow': 127.9}
# Spike detected: flow = 127.9
# Publishing reading: {'timestamp': '2025-06-02T15:43:56.001147Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 22.0, 'pressure': 3.43, 'flow': 124.5}
# Spike detected: flow = 124.5
# Publishing reading: {'timestamp': '2025-06-02T15:43:58.001883Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 36.2, 'pressure': 3.07, 'flow': 91.5}
# Publishing reading: {'timestamp': '2025-06-02T15:44:00.002143Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 30.9, 'pressure': 1.55, 'flow': 59.5}
# Publishing reading: {'timestamp': '2025-06-02T15:44:02.002411Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 24.1, 'pressure': 1.93, 'flow': 55.9}
# Publishing reading: {'timestamp': '2025-06-02T15:44:04.002632Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 23.3, 'pressure': 3.87, 'flow': 119.1}
# Publishing reading: {'timestamp': '2025-06-02T15:44:06.002877Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 23.9, 'pressure': 1.0, 'flow': 24.5}
# Publishing reading: {'timestamp': '2025-06-02T15:44:08.003143Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 35.9, 'pressure': 3.85, 'flow': 51.5}
# Publishing reading: {'timestamp': '2025-06-02T15:44:10.003397Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 17.0, 'pressure': 3.11, 'flow': 63.0}
# Publishing reading: {'timestamp': '2025-06-02T15:44:12.004087Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 33.5, 'pressure': 3.63, 'flow': 74.9}
# Publishing reading: {'timestamp': '2025-06-02T15:44:14.004955Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 27.3, 'pressure': 1.22, 'flow': 125.0}
# Spike detected: flow = 125.0
# Publishing reading: {'timestamp': '2025-06-02T15:44:16.005509Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 35.7, 'pressure': 2.57, 'flow': 44.8}
# Publishing reading: {'timestamp': '2025-06-02T15:44:18.005757Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 14.9, 'pressure': 1.25, 'flow': 116.9}
# Publishing reading: {'timestamp': '2025-06-02T15:44:20.006026Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 36.2, 'pressure': 2.19, 'flow': 96.7}
# Publishing reading: {'timestamp': '2025-06-02T15:44:22.006319Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 14.2, 'pressure': 2.19, 'flow': 108.9}
# Publishing reading: {'timestamp': '2025-06-02T15:44:24.006590Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 34.0, 'pressure': 2.68, 'flow': 116.4}
# Publishing reading: {'timestamp': '2025-06-02T15:44:26.006813Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 32.6, 'pressure': 3.47, 'flow': 125.0}
# Spike detected: flow = 125.0
# Publishing reading: {'timestamp': '2025-06-02T15:44:28.014961Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 15.3, 'pressure': 3.31, 'flow': 84.4}
# Publishing reading: {'timestamp': '2025-06-02T15:44:30.015178Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 23.6, 'pressure': 3.7, 'flow': 71.0}
# Publishing reading: {'timestamp': '2025-06-02T15:44:32.015419Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 38.8, 'pressure': 2.38, 'flow': 121.8}
# Spike detected: flow = 121.8
# Publishing reading: {'timestamp': '2025-06-02T15:44:34.016014Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 35.7, 'pressure': 2.64, 'flow': 31.2}
# Publishing reading: {'timestamp': '2025-06-02T15:44:36.016299Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 22.7, 'pressure': 2.19, 'flow': 101.8}
# Publishing reading: {'timestamp': '2025-06-02T15:44:38.016518Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 32.8, 'pressure': 3.54, 'flow': 81.0}
# Publishing reading: {'timestamp': '2025-06-02T15:44:40.016738Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 22.3, 'pressure': 2.23, 'flow': 79.3}
# Publishing reading: {'timestamp': '2025-06-02T15:44:42.017008Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 35.3, 'pressure': 1.51, 'flow': 123.3}
# Spike detected: flow = 123.3
# Publishing reading: {'timestamp': '2025-06-02T15:44:44.017667Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 34.5, 'pressure': 1.3, 'flow': 52.5}
# Publishing reading: {'timestamp': '2025-06-02T15:44:46.017916Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 25.5, 'pressure': 1.49, 'flow': 86.7}
# Publishing reading: {'timestamp': '2025-06-02T15:44:48.018136Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 18.5, 'pressure': 1.6, 'flow': 45.3}
# Publishing reading: {'timestamp': '2025-06-02T15:44:50.018422Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 19.4, 'pressure': 1.31, 'flow': 118.2}
# Publishing reading: {'timestamp': '2025-06-02T15:44:52.018669Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 30.4, 'pressure': 1.06, 'flow': 32.6}
# Publishing reading: {'timestamp': '2025-06-02T15:44:54.018883Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 11.3, 'pressure': 1.34, 'flow': 21.7}
# Publishing reading: {'timestamp': '2025-06-02T15:44:56.019130Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 22.7, 'pressure': 1.43, 'flow': 57.3}
# Publishing reading: {'timestamp': '2025-06-02T15:44:58.019414Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 16.9, 'pressure': 1.59, 'flow': 91.4}
# Publishing reading: {'timestamp': '2025-06-02T15:45:00.020360Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 20.9, 'pressure': 2.38, 'flow': 74.9}
# Publishing reading: {'timestamp': '2025-06-02T15:45:02.020659Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 26.6, 'pressure': 3.14, 'flow': 114.9}
# Publishing reading: {'timestamp': '2025-06-02T15:45:04.020887Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 35.8, 'pressure': 3.43, 'flow': 71.3}
# Publishing reading: {'timestamp': '2025-06-02T15:45:06.021253Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 37.2, 'pressure': 1.87, 'flow': 79.8}
# Publishing reading: {'timestamp': '2025-06-02T15:45:08.021486Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 33.1, 'pressure': 2.01, 'flow': 26.6}
# Publishing reading: {'timestamp': '2025-06-02T15:45:10.021742Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 19.6, 'pressure': 3.51, 'flow': 103.1}
# Publishing reading: {'timestamp': '2025-06-02T15:45:12.022040Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 12.2, 'pressure': 3.56, 'flow': 68.6}
# Publishing reading: {'timestamp': '2025-06-02T15:45:14.022285Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 24.7, 'pressure': 3.55, 'flow': 70.8}
# Publishing reading: {'timestamp': '2025-06-02T15:45:16.022511Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 16.5, 'pressure': 1.86, 'flow': 81.2}
# Publishing reading: {'timestamp': '2025-06-02T15:45:18.022765Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 11.7, 'pressure': 1.06, 'flow': 102.6}
# Publishing reading: {'timestamp': '2025-06-02T15:45:20.023102Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 20.3, 'pressure': 1.01, 'flow': 39.6}
# Publishing reading: {'timestamp': '2025-06-02T15:45:22.026212Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 16.1, 'pressure': 1.34, 'flow': 45.6}
# Publishing reading: {'timestamp': '2025-06-02T15:45:24.031116Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 37.8, 'pressure': 3.41, 'flow': 78.8}
# Publishing reading: {'timestamp': '2025-06-02T15:45:26.031921Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 28.8, 'pressure': 1.59, 'flow': 66.7}
# Publishing reading: {'timestamp': '2025-06-02T15:45:28.032574Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 21.3, 'pressure': 2.96, 'flow': 77.6}
# Publishing reading: {'timestamp': '2025-06-02T15:45:30.032850Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 27.9, 'pressure': 3.49, 'flow': 81.5}
# Publishing reading: {'timestamp': '2025-06-02T15:45:32.033101Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 12.2, 'pressure': 1.47, 'flow': 68.1}
# Publishing reading: {'timestamp': '2025-06-02T15:45:34.033388Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 22.8, 'pressure': 1.53, 'flow': 83.2}
# Publishing reading: {'timestamp': '2025-06-02T15:45:36.039308Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 20.7, 'pressure': 1.22, 'flow': 91.2}
# Publishing reading: {'timestamp': '2025-06-02T15:45:38.039672Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 13.6, 'pressure': 3.34, 'flow': 31.0}
# Publishing reading: {'timestamp': '2025-06-02T15:45:40.039945Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 12.3, 'pressure': 3.97, 'flow': 41.8}
# Publishing reading: {'timestamp': '2025-06-02T15:45:42.040145Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 32.1, 'pressure': 1.38, 'flow': 108.5}
# Publishing reading: {'timestamp': '2025-06-02T15:45:44.040361Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 15.8, 'pressure': 3.57, 'flow': 39.7}
# Publishing reading: {'timestamp': '2025-06-02T15:45:46.040579Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 19.0, 'pressure': 2.44, 'flow': 34.4}
# Publishing reading: {'timestamp': '2025-06-02T15:45:48.040855Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 16.6, 'pressure': 2.7, 'flow': 128.2}
# Spike detected: flow = 128.2
# Publishing reading: {'timestamp': '2025-06-02T15:45:50.048179Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 22.9, 'pressure': 1.21, 'flow': 48.9}
# Publishing reading: {'timestamp': '2025-06-02T15:45:52.052031Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 11.7, 'pressure': 1.49, 'flow': 60.4}
# Publishing reading: {'timestamp': '2025-06-02T15:45:54.052300Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 36.7, 'pressure': 2.04, 'flow': 78.8}
# Publishing reading: {'timestamp': '2025-06-02T15:45:56.052562Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 23.0, 'pressure': 3.74, 'flow': 108.0}
# Publishing reading: {'timestamp': '2025-06-02T15:45:58.052774Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 30.0, 'pressure': 2.08, 'flow': 46.6}
# Publishing reading: {'timestamp': '2025-06-02T15:46:00.053010Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 13.0, 'pressure': 3.27, 'flow': 116.5}
# Publishing reading: {'timestamp': '2025-06-02T15:46:02.053378Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 33.0, 'pressure': 2.42, 'flow': 85.0}
# Publishing reading: {'timestamp': '2025-06-02T15:46:04.053585Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 20.6, 'pressure': 3.39, 'flow': 29.6}
# Publishing reading: {'timestamp': '2025-06-02T15:46:06.053904Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 20.9, 'pressure': 3.37, 'flow': 76.4}
# Publishing reading: {'timestamp': '2025-06-02T15:46:08.054206Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 38.5, 'pressure': 1.11, 'flow': 123.2}
# Spike detected: flow = 123.2
# Publishing reading: {'timestamp': '2025-06-02T15:46:10.063787Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 20.7, 'pressure': 1.53, 'flow': 40.5}
# Publishing reading: {'timestamp': '2025-06-02T15:46:12.064079Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 16.5, 'pressure': 2.14, 'flow': 106.1}
# Publishing reading: {'timestamp': '2025-06-02T15:46:14.064513Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 10.0, 'pressure': 1.5, 'flow': 73.3}
# Publishing reading: {'timestamp': '2025-06-02T15:46:16.064749Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 32.6, 'pressure': 1.2, 'flow': 81.8}
# Publishing reading: {'timestamp': '2025-06-02T15:46:18.065009Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 29.4, 'pressure': 3.54, 'flow': 104.6}
# Publishing reading: {'timestamp': '2025-06-02T15:46:20.065548Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 26.0, 'pressure': 1.78, 'flow': 114.0}
# Publishing reading: {'timestamp': '2025-06-02T15:46:22.065808Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 26.4, 'pressure': 2.88, 'flow': 94.9}
# Publishing reading: {'timestamp': '2025-06-02T15:46:24.066050Z', 'sensor_id': 'wtf-pipe-1', 'temperature': 26.4, 'pressure': 3.22, 'flow': 56.3}

# %%
from langchain_ollama import OllamaLLM
from langchain.prompts import PromptTemplate

MODEL_NAME = "llama3.2"

llm = OllamaLLM(model=MODEL_NAME)
prompt = PromptTemplate.from_template("""
            As a water treatment system analyst. 
            Analyze the following anomalies and provide a very concise report/summary.

            Focus on:
            1. Most critical and recent issues
            2. Patterns or trends in the anomalies

            Anomaly Data:
            {anomaly_text}

            Provide a concise and structured summary with severity levels and actionable insights.
            Do not Hallucinate or make up data.
        """)
llm_chain = prompt | llm

def generate_summary():
    with open("storage/anomaly_log.json") as f:
        lines = f.readlines()[-10:]
    text = "\n".join(lines)
    # return llm_chain.invoke({"anomaly_text": text})
    formatted_prompt = prompt.format(anomaly_text=text)
    return llm_chain.invoke(input=formatted_prompt)

generated_summary = generate_summary()

# %%
print(generated_summary)
# Out:
# **Summary Report: Water Treatment System Anomalies**
#
# **Most Critical and Recent Issues:**
#
# 1. **Flow Spike (High Priority)**:
# 	* Timestamp: 2025-06-02T15:43:54.000468Z
# 	* Value: 127.9
# 	* Cause: Unidentified external influence on the pipe, potentially due to a blockage or sedimentation.
# 2. **Flow Surge (Medium-High Priority)**:
# 	* Timestamp: 2025-06-02T15:45:48.040855Z
# 	* Value: 128.2
# 	* Cause: Possible sudden increase in water demand or external pressure on the pipe.
#
# **Patterns or Trends:**
#
# 1. **Spike Frequency**: The number of flow spikes has increased over a short period (2025-06-02T15:43:54.000468Z to 2025-06-02T15:46:08.054206Z).
# 2. **Value Range**: Flow values have fluctuated between 121.8 and 128.2, indicating potential external influences or equipment malfunctions.
# 3. **Sensor Stability**: The flow sensor has shown variability in its readings, suggesting a possible issue with the sensor's calibration or installation.
#
# **Actionable Insights:**
#
# 1. Investigate the cause of the recent flow spikes and take corrective action to prevent future incidents.
# 2. Monitor the flow sensor's performance and adjust its settings if necessary to ensure accurate readings.
# 3. Inspect the pipe for any blockages, sedimentation, or external influences that could be causing the fluctuations.
#
# **Recommendations:**
#
# 1. Perform a thorough analysis of the water treatment system to identify potential causes of the anomalies.
# 2. Implement real-time monitoring and alert systems to quickly respond to future incidents.
# 3. Schedule regular maintenance and inspections to ensure equipment and sensors are functioning correctly.
#
# Note: Severity levels are subjective and based on the impact and frequency of the anomalies.

# %%
import threading
import time
import redis

server = redis.Redis()

def subscriber():
    sub = server.pubsub()
    sub.subscribe('sensor_data')
    print("Subscribed. Waiting for messages...")
    for msg in sub.listen():
        if msg['type'] == 'message':
            print(f"Received: {msg['data'].decode('utf-8')}")

def publisher():
    SENSOR_ID = "wtf-pipe-1"
    for count in range(5):
        reading = f"Testing {SENSOR_ID}: Count - {count}"
        server.publish('sensor_data', reading)
        print(f"Published: {reading}")
        time.sleep(1)

# Start subscriber in a separate thread
threading.Thread(target=subscriber, daemon=True).start()

# Wait a bit and then start publishing
time.sleep(2)
publisher()
# Out:
# Subscribed. Waiting for messages...
# Published: Testing wtf-pipe-1: Count - 0
# Received: Testing wtf-pipe-1: Count - 0
# Published: Testing wtf-pipe-1: Count - 1
# Received: Testing wtf-pipe-1: Count - 1
# Published: Testing wtf-pipe-1: Count - 2
# Received: Testing wtf-pipe-1: Count - 2
# Published: Testing wtf-pipe-1: Count - 3Received: Testing wtf-pipe-1: Count - 3
#
# Received: Testing wtf-pipe-1: Count - 4Published: Testing wtf-pipe-1: Count - 4
